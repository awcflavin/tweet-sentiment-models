# %% [markdown]
# This notebook contains code for hyperparameter searching for some of the models. Data related to the hyperparm search is saved to "logs/optuna.db". This can be easily visualized and analyzed using the Optuna VSCode Extension or otherwise.

# %%
from __future__ import print_function

import torch

import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

from models.LSTMs import LSTMWithWC, LSTM
from models.transformers import Encoder
from models.MLP import MLP

from utils.tokenizers import *
from utils.datasets import *
from utils.utils import clean_original_content
import random
device = "cuda" if torch.cuda.is_available() else "cpu"

import optuna

# Set the seeds
seed = 2024
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
data = pd.read_csv('data/dataset(clean).csv')
data = shuffle(data, random_state=seed)

# data should be the same as training set in train.py - no peeking at test set
data = data.iloc[:10000]

train_n = round(len(data)*0.8)

train_data = data.iloc[:train_n]
val_data = data.iloc[train_n:]

emotion_to_int = {
    "disappointed": 0,
    "happy": 1,
    "angry": 2,
}
    
labels_train = torch.tensor(list(train_data.Emotion.map(lambda x: emotion_to_int[x])))
labels_val = torch.tensor(list(val_data.Emotion.map(lambda x: emotion_to_int[x])))

tweets_train = list(train_data.OriginalContent)
tweets_val = list(val_data.OriginalContent)

tweets_train = clean_original_content(tweets_train)
tweets_val = clean_original_content(tweets_val)

# %%
batch_size = 64
block_size = 128

# %%
# using BPE tokenizer for all classifiers here
tokenizer = CustomBPETokenizer(use_existing_tokenizer=True, use_existing_tokens=True)

# %% [markdown]
# ### MLP
# **NOTE:** hyperparameters chosen for MLP were also used for MLPWithFastText

# %%
def train_mlp(lr, wd, emb_dim, hidden_dim):
    model = MLP(tokenizer.get_vocab_size(), emb_dim=emb_dim, block_size=block_size, hidden_dim=hidden_dim, num_classes=3).to(device)
    train_dataset = model.get_dataset(tweets_train, labels_train, tokenizer, tag='hparam_search_train')
    val_dataset = model.get_dataset(tweets_val, labels_val, tokenizer, tag='hparam_search_val')
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    train_loss, val_loss, train_acc, val_acc = model.train_model(train_dataset, val_dataset, optimizer, batch_size)
    return val_loss

def objective(trial):
    lr = trial.suggest_float("lr", 1e-4, 1e-1)
    wd = trial.suggest_float("wd", 1e-4, 1e-2)
    emb_dim = 2** trial.suggest_int("emb_dim_exponent", 4, 6)
    hidden_dim = 2** trial.suggest_int("hidden_dim_exponent", 6, 8)
    return train_mlp(lr, wd, emb_dim, hidden_dim)

study = optuna.create_study(direction='minimize', study_name='MLPWithFastText Study',  storage='sqlite:///logs/optuna.db')
study.optimize(objective, n_trials=30)

best_params = study.best_params
print(f'Best params: {best_params}')
# Out:
# [I 2024-05-02 20:52:18,467] A new study created in RDB with name: MLPWithFastText Study
# 100%|██████████| 125/125 [00:00<00:00, 296.98batch/s]
# [I 2024-05-02 20:52:20,169] Trial 0 finished with value: 1.0976 and parameters: {'lr': 0.06606611713357255, 'wd': 0.0005542785283686457, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6}. Best is trial 0 with value: 1.0976.
# 100%|██████████| 125/125 [00:00<00:00, 415.57batch/s]
# [I 2024-05-02 20:52:21,363] Trial 1 finished with value: 0.9435 and parameters: {'lr': 0.0974274316093112, 'wd': 0.002451206240418282, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 434.36batch/s]
# [I 2024-05-02 20:52:22,568] Trial 2 finished with value: 1.0069 and parameters: {'lr': 0.08551211243929724, 'wd': 0.0016987806218184852, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 441.20batch/s]
# [I 2024-05-02 20:52:23,641] Trial 3 finished with value: 0.9486 and parameters: {'lr': 0.02189979777507528, 'wd': 0.00021035385497386963, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 422.61batch/s]
# [I 2024-05-02 20:52:24,835] Trial 4 finished with value: 1.1013 and parameters: {'lr': 0.062358388738914985, 'wd': 0.004636815932694135, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 8}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 430.86batch/s]
# [I 2024-05-02 20:52:26,033] Trial 5 finished with value: 1.044 and parameters: {'lr': 0.042616803656205626, 'wd': 0.003433547735328076, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 416.91batch/s]
# [I 2024-05-02 20:52:27,145] Trial 6 finished with value: 1.0736 and parameters: {'lr': 0.04978303063891275, 'wd': 0.008235741798254792, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 399.61batch/s]
# [I 2024-05-02 20:52:28,385] Trial 7 finished with value: 1.0722 and parameters: {'lr': 0.031191608796420883, 'wd': 0.00023994261595165794, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6}. Best is trial 1 with value: 0.9435.
# 100%|██████████| 125/125 [00:00<00:00, 401.53batch/s]
# [I 2024-05-02 20:52:29,510] Trial 8 finished with value: 0.9408 and parameters: {'lr': 0.043101161743895874, 'wd': 0.0026247095013457724, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 7}. Best is trial 8 with value: 0.9408.
# 100%|██████████| 125/125 [00:00<00:00, 412.83batch/s]
# [I 2024-05-02 20:52:30,740] Trial 9 finished with value: 1.0991 and parameters: {'lr': 0.035895180736783674, 'wd': 0.003913458240133608, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7}. Best is trial 8 with value: 0.9408.
# 100%|██████████| 125/125 [00:00<00:00, 368.92batch/s]
# [I 2024-05-02 20:52:32,053] Trial 10 finished with value: 0.8938 and parameters: {'lr': 0.0030983768522818353, 'wd': 0.006381654206995037, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7}. Best is trial 10 with value: 0.8938.
# 100%|██████████| 125/125 [00:00<00:00, 411.46batch/s]
# [I 2024-05-02 20:52:33,166] Trial 11 finished with value: 0.9262 and parameters: {'lr': 0.000867785162002449, 'wd': 0.007174469923330493, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7}. Best is trial 10 with value: 0.8938.
# 100%|██████████| 125/125 [00:00<00:00, 407.03batch/s]
# [I 2024-05-02 20:52:34,415] Trial 12 finished with value: 0.9933 and parameters: {'lr': 0.006291534649393695, 'wd': 0.007010751360446512, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7}. Best is trial 10 with value: 0.8938.
# 100%|██████████| 125/125 [00:00<00:00, 415.57batch/s]
# [I 2024-05-02 20:52:35,661] Trial 13 finished with value: 0.8665 and parameters: {'lr': 0.0035524933572427322, 'wd': 0.0063867952907142875, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7}. Best is trial 13 with value: 0.8665.
# 100%|██████████| 125/125 [00:00<00:00,
 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7}

# %% [markdown]
# ### Encoder

# %%
def train_encoder(lr, wd, emb_dim, heads, blocks):
    model = Encoder(tokenizer.get_vocab_size(), emb_dim=emb_dim, block_size=block_size, num_classes=3, heads=heads, blocks=blocks).to(device)
    train_dataset = model.get_dataset(tweets_train, labels_train, tokenizer, tag='hparam_search_train')
    val_dataset = model.get_dataset(tweets_val, labels_val, tokenizer, tag='hparam_search_val')

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    train_loss, val_loss, train_acc, val_acc = model.train_model(train_dataset, val_dataset, optimizer, batch_size)
    return val_loss

def objective(trial):
    lr = trial.suggest_float("lr", 1e-4, 1e-1)
    wd = trial.suggest_float("wd", 1e-4, 1e-2)
    emb_dim = 2** trial.suggest_int("emb_dim_exponent", 4, 6)
    heads = 2** trial.suggest_int("heads_exponent", 1, 4)
    if heads > emb_dim: # head size = dim/heads
        return float('inf')
    blocks = trial.suggest_int("blocks", 1, 4)
    return train_encoder(lr, wd, emb_dim, heads, blocks)

study = optuna.create_study(direction='minimize', study_name='Encoder Study', storage='sqlite:///logs/optuna.db')
study.optimize(objective, n_trials=30)

best_params = study.best_params
print(f'Best params: {best_params}')
# Out:
# [I 2024-05-02 20:52:55,018] A new study created in RDB with name: Encoder Study
# 100%|██████████| 125/125 [00:00<00:00, 166.55batch/s]
# [I 2024-05-02 20:52:56,788] Trial 0 finished with value: 1.8823 and parameters: {'lr': 0.09432714831791314, 'wd': 0.006101943445563018, 'emb_dim_exponent': 4, 'heads_exponent': 1, 'blocks': 1}. Best is trial 0 with value: 1.8823.
# 100%|██████████| 125/125 [00:01<00:00, 73.43batch/s]
# [I 2024-05-02 20:52:59,507] Trial 1 finished with value: 22.1904 and parameters: {'lr': 0.055598962254645105, 'wd': 0.008006598324454977, 'emb_dim_exponent': 6, 'heads_exponent': 2, 'blocks': 2}. Best is trial 0 with value: 1.8823.
# 100%|██████████| 125/125 [00:01<00:00, 72.88batch/s]
# [I 2024-05-02 20:53:02,364] Trial 2 finished with value: 2.5117 and parameters: {'lr': 0.01677529300702094, 'wd': 0.008657999196414986, 'emb_dim_exponent': 5, 'heads_exponent': 2, 'blocks': 2}. Best is trial 0 with value: 1.8823.
# 100%|██████████| 125/125 [00:02<00:00, 47.62batch/s]
# [I 2024-05-02 20:53:06,236] Trial 3 finished with value: 1.0666 and parameters: {'lr': 0.006671799937419533, 'wd': 0.0036977153758981068, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 2}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:05<00:00, 24.51batch/s]
# [I 2024-05-02 20:53:12,849] Trial 4 finished with value: 3.4204 and parameters: {'lr': 0.013442414946690214, 'wd': 0.006805211825985169, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 4}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:02<00:00, 41.74batch/s]
# [I 2024-05-02 20:53:17,188] Trial 5 finished with value: 388.3619 and parameters: {'lr': 0.06799946277278876, 'wd': 0.0009724389325847846, 'emb_dim_exponent': 6, 'heads_exponent': 2, 'blocks': 4}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:01<00:00, 83.97batch/s]
# [I 2024-05-02 20:53:19,806] Trial 6 finished with value: 142.2345 and parameters: {'lr': 0.0728271636052336, 'wd': 0.007624130228275961, 'emb_dim_exponent': 5, 'heads_exponent': 1, 'blocks': 3}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:01<00:00, 81.50batch/s]
# [I 2024-05-02 20:53:22,326] Trial 7 finished with value: 8.0812 and parameters: {'lr': 0.09032277297035571, 'wd': 0.0013998512493172586, 'emb_dim_exponent': 4, 'heads_exponent': 1, 'blocks': 3}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:00<00:00, 127.99batch/s]
# [I 2024-05-02 20:53:24,341] Trial 8 finished with value: 14.7048 and parameters: {'lr': 0.04474258925876659, 'wd': 0.005271430989236943, 'emb_dim_exponent': 6, 'heads_exponent': 2, 'blocks': 1}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:02<00:00, 50.94batch/s]
# [I 2024-05-02 20:53:28,026] Trial 9 finished with value: 1.6902 and parameters: {'lr': 0.09251817197168134, 'wd': 0.004356091543080723, 'emb_dim_exponent': 4, 'heads_exponent': 4, 'blocks': 1}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:04<00:00, 25.71batch/s]
# [I 2024-05-02 20:53:34,274] Trial 10 finished with value: 1.0713 and parameters: {'lr': 0.0007677745646592149, 'wd': 0.0032457652133136596, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 2}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:04<00:00, 27.86batch/s]
# [I 2024-05-02 20:53:40,270] Trial 11 finished with value: 1.1712 and parameters: {'lr': 0.0011836138380632091, 'wd': 0.003257511159911971, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 2}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:02<00:00, 47.51batch/s]
# [I 2024-05-02 20:53:44,234] Trial 12 finished with value: 4.5726 and parameters: {'lr': 0.029892820110650177, 'wd': 0.003146977921295319, 'emb_dim_exponent': 5, 'heads_exponent': 3, 'blocks': 2}. Best is trial 3 with value: 1.0666.
# 100%|██████████| 125/125 [00:06<00:00, 18.13batch/s]
# [I 2024-05-02 20:53:52,884] Trial 13 finished with value: 1.03 and parameters: {'lr': 0.003442265985278323, 'wd': 0.0025031898639930688, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 3}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:03<00:00, 32.11batch/s]
# [I 2024-05-02 20:53:58,202] Trial 14 finished with value: 44.9935 and parameters: {'lr': 0.0329340586546765, 'wd': 0.0001954618193090638, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 3}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:06<00:00, 18.60batch/s]
# [I 2024-05-02 20:54:06,725] Trial 15 finished with value: 1.1024 and parameters: {'lr': 0.0184105213752836, 'wd': 0.0018545417937006143, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 3}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:04<00:00, 25.48batch/s]
# [I 2024-05-02 20:54:13,102] Trial 16 finished with value: 97.9623 and parameters: {'lr': 0.030629321644165614, 'wd': 0.004639894743953827, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 4}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:06<00:00, 19.58batch/s]
# [I 2024-05-02 20:54:21,242] Trial 17 finished with value: 1.0683 and parameters: {'lr': 0.008622220429409659, 'wd': 0.0028393707514873683, 'emb_dim_exponent': 4, 'heads_exponent': 4, 'blocks': 3}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:02<00:00, 47.79batch/s]
# [I 2024-05-02 20:54:25,144] Trial 18 finished with value: 1.0558 and parameters: {'lr': 0.02541315529339925, 'wd': 0.009479748397681946, 'emb_dim_exponent': 5, 'heads_exponent': 3, 'blocks': 2}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:06<00:00, 18.78batch/s]
# [I 2024-05-02 20:54:33,466] Trial 19 finished with value: 2.5307 and parameters: {'lr': 0.04214500759787146, 'wd': 0.009094627854103301, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 3}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:01<00:00, 79.70batch/s]
# [I 2024-05-02 20:54:36,189] Trial 20 finished with value: 1.1347 and parameters: {'lr': 0.021780329189818728, 'wd': 0.009769939125095762, 'emb_dim_exponent': 4, 'heads_exponent': 3, 'blocks': 1}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:02<00:00, 44.73batch/s]
# [I 2024-05-02 20:54:40,269] Trial 21 finished with value: 1.0982 and parameters: {'lr': 0.007150973905246705, 'wd': 0.0023737823990992455, 'emb_dim_exponent': 5, 'heads_exponent': 3, 'blocks': 2}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:02<00:00, 47.43batch/s]
# [I 2024-05-02 20:54:44,075] Trial 22 finished with value: 2.1537 and parameters: {'lr': 0.024455837656852844, 'wd': 0.004030250794523063, 'emb_dim_exponent': 5, 'heads_exponent': 3, 'blocks': 2}. Best is trial 13 with value: 1.03.
# 100%|██████████| 125/125 [00:02<00:00, 48.75batch/s]
# [I 2024-05-02 20:54:47,922] Trial 23 finished with value: 0.9732 and parameters: {'lr': 0.010405639409764685, 'wd': 0.006273954885390327, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 2}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:06<00:00, 18.67batch/s]
# [I 2024-05-02 20:54:56,438] Trial 24 finished with value: 3.8258 and parameters: {'lr': 0.038362938476793576, 'wd': 0.005694190184038824, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 3}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:01<00:00, 71.72batch/s]
# [I 2024-05-02 20:54:59,224] Trial 25 finished with value: 1.1819 and parameters: {'lr': 0.012690000996379616, 'wd': 0.006683004731666773, 'emb_dim_exponent': 5, 'heads_exponent': 2, 'blocks': 2}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:01<00:00, 83.25batch/s]
# [I 2024-05-02 20:55:01,852] Trial 26 finished with value: 9.4354 and parameters: {'lr': 0.05747084374930225, 'wd': 0.007730967586762179, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 1}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:06<00:00, 18.73batch/s]
# [I 2024-05-02 20:55:10,335] Trial 27 finished with value: 1.2662 and parameters: {'lr': 0.01882987094652203, 'wd': 0.009773805206313395, 'emb_dim_exponent': 5, 'heads_exponent': 4, 'blocks': 3}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:04<00:00, 25.23batch/s]
# [I 2024-05-02 20:55:16,756] Trial 28 finished with value: 16.889 and parameters: {'lr': 0.02471544605722582, 'wd': 0.006432447931397706, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 4}. Best is trial 23 with value: 0.9732.
# 100%|██████████| 125/125 [00:00<00:00, 132.36batch/s]
# [I 2024-05-02 20:55:18,774] Trial 29 finished with value: 1.1012 and parameters: {'lr': 0.0002585595936083762, 'wd': 0.005906574363487233, 'emb_dim_exponent': 4, 'heads_exponent': 2, 'blocks': 1}. Best is trial 23 with value: 0.9732.
# Best params: {'lr': 0.010405639409764685, 'wd': 0.006273954885390327, 'emb_dim_exponent': 6, 'heads_exponent': 3, 'blocks': 2}

# %% [markdown]
# ### LSTM With WC

# %%
def train_lstm_with_wc(lr, wd, emb_dim, hidden_dim, bidirectional):
    model = LSTMWithWC(tokenizer.get_vocab_size(), emb_dim=emb_dim, hidden_dim=hidden_dim, num_classes=3, bidirectional=bidirectional).to(device)
    train_dataset = model.get_dataset(tweets_train, labels_train, tokenizer, tag='hparam_search_train')
    val_dataset = model.get_dataset(tweets_val, labels_val, tokenizer, tag='hparam_search_val')
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    train_loss, val_loss, train_acc, val_acc = model.train_model(train_dataset, val_dataset, optimizer, batch_size)
    return val_loss

def objective(trial):
    lr = trial.suggest_float("lr", 1e-4, 1e-1)
    wd = trial.suggest_float("wd", 1e-4, 1e-2)
    emb_dim = 2** trial.suggest_int("emb_dim_exponent", 4, 6)
    hidden_dim = 2** trial.suggest_int("hidden_dim_exponent", 6, 8)
    bidirectional = trial.suggest_categorical("bidirectional", [True, False])
    return train_lstm_with_wc(lr, wd, emb_dim, hidden_dim, bidirectional)

study = optuna.create_study(direction='minimize', study_name='LSTMWithWC Study',  storage='sqlite:///logs/optuna.db')
study.optimize(objective, n_trials=30)

best_params = study.best_params
print(f'Best params: {best_params}')
# Out:
# [I 2024-05-02 20:55:18,871] A new study created in RDB with name: LSTMWithWC Study
# 100%|██████████| 125/125 [00:11<00:00, 10.70batch/s]
# [I 2024-05-02 20:55:32,431] Trial 0 finished with value: 1.1344 and parameters: {'lr': 0.056000803353149727, 'wd': 0.0026616276603737363, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial
 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7, 'bidirectional': True}

# %% [markdown]
# ### LSTM

# %%
def train_lstm_with_wc(lr, wd, emb_dim, hidden_dim, bidirectional):
    model = LSTM(tokenizer.get_vocab_size(), emb_dim=emb_dim, hidden_dim=hidden_dim, num_classes=3, bidirectional=bidirectional).to(device)
    train_dataset = model.get_dataset(tweets_train, labels_train, tokenizer, tag='hparam_search_train')
    val_dataset = model.get_dataset(tweets_val, labels_val, tokenizer, tag='hparam_search_val')

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    train_loss, val_loss, train_acc, val_acc = model.train_model(train_dataset, val_dataset, optimizer, batch_size)
    return val_loss

def objective(trial):
    lr = trial.suggest_float("lr", 1e-4, 1e-1)
    wd = trial.suggest_float("wd", 1e-4, 1e-2)
    emb_dim = 2** trial.suggest_int("emb_dim_exponent", 4, 6)
    hidden_dim = 2** trial.suggest_int("hidden_dim_exponent", 6, 8)
    bidirectional = trial.suggest_categorical("bidirectional", [True, False])
    return train_lstm_with_wc(lr, wd, emb_dim, hidden_dim, bidirectional)

study = optuna.create_study(direction='minimize', study_name='LSTM Study',  storage='sqlite:///logs/optuna.db')
study.optimize(objective, n_trials=30)

best_params = study.best_params
print(f'Best params: {best_params}')
# Out:
# [I 2024-05-02 21:06:04,897] A new study created in RDB with name: LSTM Study
# 100%|██████████| 125/125 [00:02<00:00, 61.19batch/s]
# [I 2024-05-02 21:06:08,061] Trial 0 finished with value: 0.9987 and parameters: {'lr': 0.07506101972874252, 'wd': 0.009470351957146378, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 6, 'bidirectional': True}. Best is trial 0 with value: 0.9987.
# 100%|██████████| 125/125 [00:02<00:00, 62.03batch/s]
# [I 2024-05-02 21:06:10,995] Trial 1 finished with value: 0.8738 and parameters: {'lr': 0.042060929078430495, 'wd': 0.0018129209212587678, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': True}. Best is trial 1 with value: 0.8738.
# 100%|██████████| 125/125 [00:01<00:00, 81.54batch/s]
# [I 2024-05-02 21:06:13,516] Trial 2 finished with value: 0.9755 and parameters: {'lr': 0.07306580603639927, 'wd': 0.007691253955753859, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 1 with value: 0.8738.
# 100%|██████████| 125/125 [00:02<00:00, 60.72batch/s]
# [I 2024-05-02 21:06:16,543] Trial 3 finished with value: 0.9374 and parameters: {'lr': 0.01576797361821376, 'wd': 0.008172636332491046, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 6, 'bidirectional': True}. Best is trial 1 with value: 0.8738.
# 100%|██████████| 125/125 [00:01<00:00, 77.67batch/s]
# [I 2024-05-02 21:06:19,153] Trial 4 finished with value: 0.8463 and parameters: {'lr': 0.013646098278797059, 'wd': 0.0010111089654707883, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:01<00:00, 77.85batch/s]
# [I 2024-05-02 21:06:21,618] Trial 5 finished with value: 1.5945 and parameters: {'lr': 0.08100770122844105, 'wd': 0.004514865486211878, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8, 'bidirectional': False}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:01<00:00, 62.95batch/s]
# [I 2024-05-02 21:06:24,647] Trial 6 finished with value: 0.9228 and parameters: {'lr': 0.09579921924080989, 'wd': 0.002996640888429639, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 7, 'bidirectional': True}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:01<00:00, 63.58batch/s]
# [I 2024-05-02 21:06:27,556] Trial 7 finished with value: 0.9383 and parameters: {'lr': 0.004145688445032907, 'wd': 0.00219761579886828, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 7, 'bidirectional': True}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:02<00:00, 61.46batch/s]
# [I 2024-05-02 21:06:30,624] Trial 8 finished with value: 0.8957 and parameters: {'lr': 0.07886080807158961, 'wd': 0.000550873224546897, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 8, 'bidirectional': True}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:02<00:00, 62.22batch/s]
# [I 2024-05-02 21:06:33,687] Trial 9 finished with value: 0.9543 and parameters: {'lr': 0.08632323992366014, 'wd': 0.006934495007583632, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 6, 'bidirectional': True}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:01<00:00, 82.33batch/s]
# [I 2024-05-02 21:06:36,081] Trial 10 finished with value: 0.9135 and parameters: {'lr': 0.038018031367259425, 'wd': 0.004899905929709596, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 4 with value: 0.8463.
# 100%|██████████| 125/125 [00:01<00:00, 81.97batch/s]
# [I 2024-05-02 21:06:38,601] Trial 11 finished with value: 0.7781 and parameters: {'lr': 0.038006617495726355, 'wd': 0.00021573873434164602, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 80.95batch/s]
# [I 2024-05-02 21:06:41,009] Trial 12 finished with value: 0.801 and parameters: {'lr': 0.022787145024962936, 'wd': 0.00029870891786343366, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 80.59batch/s]
# [I 2024-05-02 21:06:43,564] Trial 13 finished with value: 0.7785 and parameters: {'lr': 0.028755927785374308, 'wd': 0.00021283716783586522, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 80.83batch/s]
# [I 2024-05-02 21:06:45,991] Trial 14 finished with value: 0.9261 and parameters: {'lr': 0.05506020977873978, 'wd': 0.003426697244107311, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 80.74batch/s]
# [I 2024-05-02 21:06:48,541] Trial 15 finished with value: 1.2225 and parameters: {'lr': 0.03179044084243962, 'wd': 0.00012060007002474396, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 83.96batch/s]
# [I 2024-05-02 21:06:50,901] Trial 16 finished with value: 0.9423 and parameters: {'lr': 0.05577713902602442, 'wd': 0.006083011232930295, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 84.19batch/s]
# [I 2024-05-02 21:06:53,379] Trial 17 finished with value: 0.9149 and parameters: {'lr': 0.0625114105001377, 'wd': 0.0017392115616635213, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 8, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 83.10batch/s]
# [I 2024-05-02 21:06:55,888] Trial 18 finished with value: 0.91 and parameters: {'lr': 0.028147286247528925, 'wd': 0.0030479722361502638, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 82.86batch/s]
# [I 2024-05-02 21:06:58,265] Trial 19 finished with value: 0.902 and parameters: {'lr': 0.043147389560955075, 'wd': 0.003975284140611798, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 7, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 81.89batch/s]
# [I 2024-05-02 21:07:00,809] Trial 20 finished with value: 0.9921 and parameters: {'lr': 0.0005752061960526827, 'wd': 0.005828188396650194, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 8, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 83.25batch/s]
# [I 2024-05-02 21:07:03,184] Trial 21 finished with value: 0.8109 and parameters: {'lr': 0.022528585362003268, 'wd': 0.001125130686916817, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 11 with value: 0.7781.
# 100%|██████████| 125/125 [00:01<00:00, 80.92batch/s]
# [I 2024-05-02 21:07:05,745] Trial 22 finished with value: 0.7682 and parameters: {'lr': 0.015879729475611434, 'wd': 0.00019051865663229051, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 81.92batch/s]
# [I 2024-05-02 21:07:08,150] Trial 23 finished with value: 0.8775 and parameters: {'lr': 0.010286938445759196, 'wd': 0.002186292771341052, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 84.01batch/s]
# [I 2024-05-02 21:07:10,639] Trial 24 finished with value: 0.7932 and parameters: {'lr': 0.027029593903425905, 'wd': 0.0011635885028008024, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 83.08batch/s]
# [I 2024-05-02 21:07:13,010] Trial 25 finished with value: 0.7718 and parameters: {'lr': 0.036359326031306004, 'wd': 0.00021147633186661572, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 83.58batch/s]
# [I 2024-05-02 21:07:15,501] Trial 26 finished with value: 0.8067 and parameters: {'lr': 0.03763060467851934, 'wd': 0.0011759627559634125, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 82.95batch/s]
# [I 2024-05-02 21:07:18,000] Trial 27 finished with value: 0.8656 and parameters: {'lr': 0.06573666651353915, 'wd': 0.002513780809742341, 'emb_dim_exponent': 5, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 84.57batch/s]
# [I 2024-05-02 21:07:20,338] Trial 28 finished with value: 0.841 and parameters: {'lr': 0.05148503335410608, 'wd': 0.0013942777044403658, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# 100%|██████████| 125/125 [00:01<00:00, 83.26batch/s]
# [I 2024-05-02 21:07:22,842] Trial 29 finished with value: 0.7923 and parameters: {'lr': 0.04490641462640638, 'wd': 0.0007999142179873237, 'emb_dim_exponent': 6, 'hidden_dim_exponent': 6, 'bidirectional': False}. Best is trial 22 with value: 0.7682.
# Best params: {'lr': 0.015879729475611434, 'wd': 0.00019051865663229051, 'emb_dim_exponent': 4, 'hidden_dim_exponent': 6, 'bidirectional': False}
